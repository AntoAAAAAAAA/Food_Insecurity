# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %%
t09_data = pd.read_excel('data/MMG2025_Data_ToShare/MMG2011_2009Data_ToShare.xlsx', sheet_name='County')
t10_data = pd.read_excel('data/MMG2025_Data_ToShare/MMG2012_2010Data_ToShare.xlsx', sheet_name='County')
t11_data = pd.read_excel('data/MMG2025_Data_ToShare/MMG2013_2011Data_ToShare.xlsx', sheet_name='2011 County')
t12_data = pd.read_excel('data/MMG2025_Data_ToShare/MMG2014_2012Data_ToShare.xlsx', sheet_name='2012 County')
t13_data = pd.read_excel('data/MMG2025_Data_ToShare/MMG2015_2013Data_ToShare.xlsx', sheet_name='2013 County')
t14_data = pd.read_excel('data/MMG2025_Data_ToShare/MMG2016_2014Data_ToShare.xlsx', sheet_name='2014 County')
t15_data = pd.read_excel('data/MMG2025_Data_ToShare/MMG2017_2015Data_ToShare.xlsx', sheet_name='2015 County')
t16_data = pd.read_excel('data/MMG2025_Data_ToShare/MMG2018_2016Data_ToShare.xlsx', sheet_name='2016 County')
t17_data = pd.read_excel('data/MMG2025_Data_ToShare/MMG2019_2017Data_ToShare.xlsx', sheet_name='2017 County')
t18_data = pd.read_excel('data/MMG2025_Data_ToShare/MMG2020_2018Data_ToShare.xlsx', sheet_name='2018 County')
t19_23_data = pd.read_excel('data/MMG2025_Data_ToShare/MMG2025_2019-2023_Data_To_Share.xlsx', sheet_name='County')

# %%
###Important
'''Turns out that due to methodological changes in 2020, data prior to 2020 cannot 
be compared to data gathered from 2020 and beyond'''
'''This means we can either two do different analyses, or just stick with 2020 and beyond (which
would technically just be 1 dataset)'''

# %%
t18_data = t18_data.rename(columns=t18_data.iloc[0]).drop(t18_data.index[0]).reset_index(drop=True)

"""
Cell generated by Data Wrangler.
"""
def clean_data(t18_data):
    # Drop column: '2018 Cost Per Meal'
    t18_data = t18_data.drop(columns=['2018 Cost Per Meal'])
    # Drop column: '2018 Weighted Annual Food Budget Shortfall'
    t18_data = t18_data.drop(columns=['2018 Weighted Annual Food Budget Shortfall'])
    return t18_data

t18_data_clean = clean_data(t18_data.copy())
t18_data_clean
# Out:
#        FIPS State               County, State 2018 Food Insecurity Rate  \
# 0      1001    AL     Autauga County, Alabama                     0.156
# 1      1003    AL     Baldwin County, Alabama                     0.129
# 2      1005    AL     Barbour County, Alabama                     0.219
# 3      1007    AL        Bibb County, Alabama                     0.151
# 4      1009    AL      Blount County, Alabama                     0.136
# ...     ...   ...                         ...                       ...
# 3137  56037    WY  Sweetwater County, Wyoming                     0.117
# 3138  56039    WY       Teton County, Wyoming                     0.095
# 3139  56041    WY       Uinta County, Wyoming                     0.135
# 3140  56043    WY    Washakie County, Wyoming                     0.126
# 3141  56045    WY      Weston County, Wyoming                      0.14
#
#      # of Food Insecure Persons in 2018 Low Threshold in state  \
# ...

# %%
t18_data_clean['County, State'] = t18_data_clean['County, State'].str.replace(r',.*', '',regex=True)
t18_data_clean['County, State'] = t18_data_clean['County, State'].str.replace(r'County.*', '',regex=True)
t18_data_clean = t18_data_clean[t18_data_clean['State'] == 'TX']
t18_data_clean

### 2018 Data is clean
# Out:
#        FIPS State County, State 2018 Food Insecurity Rate  \
# 2523  48001    TX     Anderson                      0.152
# 2524  48003    TX      Andrews                      0.101
# 2525  48005    TX     Angelina                      0.179
# 2526  48007    TX      Aransas                      0.184
# 2527  48009    TX       Archer                      0.132
# ...     ...   ...           ...                       ...
# 2772  48499    TX         Wood                      0.168
# 2773  48501    TX       Yoakum                      0.093
# 2774  48503    TX        Young                       0.14
# 2775  48505    TX       Zapata                      0.208
# 2776  48507    TX       Zavala                      0.225
#
#      # of Food Insecure Persons in 2018 Low Threshold in state  \
# 2523                               8800                   1.65
# 2524                               1800                   1.65
# 2525                              15640                   1.65
# ...

# %%
t19_23_data['County, State'] = t19_23_data['County, State'].str.replace(r' County.*','',regex=True)
t19_23_data = t19_23_data[t19_23_data['State'] == 'TX']
t19_23_data = t19_23_data.drop(columns=['FIPS', 'Rural-Urban Continuum Code (2013)', 'Rural-Urban Continuum Code (2023)', 'Census Region', 'Census Division', 'FNS Region']).copy()
t19_23_data

### 2019 to 2023 Data is cleaned out
# Out:
#       State County, State  Year  Overall Food Insecurity Rate  \
# 12621    TX      Anderson  2019                         0.145
# 12622    TX       Andrews  2019                         0.098
# 12623    TX      Angelina  2019                         0.173
# 12624    TX       Aransas  2019                         0.182
# 12625    TX        Archer  2019                         0.142
# ...     ...           ...   ...                           ...
# 13886    TX          Wood  2023                         0.183
# 13887    TX        Yoakum  2023                         0.165
# 13888    TX         Young  2023                         0.185
# 13889    TX        Zapata  2023                         0.271
# 13890    TX        Zavala  2023                         0.284
#
#        # of Food Insecure Persons Overall  \
# 12621                              8400.0
# 12622                              1760.0
# 12623                             15090.0
# 12624                              4450.0
# ...

# %% [markdown]
# Questions:
#
# What counties have the highest food insecurity rates?
#
# What counties have high food insecurity rates among minorities? (black and hispanic people)
#
# What counties have highest % FI > SNAP Threshold (percent of food insecure people over the SNAP income threshold)?
